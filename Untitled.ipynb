# %%
def num_of_factors(num):
    factors=[i for i in range(1,num+1) if num%i==0]
    print(factors)
    return len(factors)
num=int(input('enter the integer:'))
print(num_of_factors(num))
# Out:
#   File "<ipython-input-7-7ad2e98062c8>", line 5
#     num=int(input(enter the integer:))
#                           ^
# SyntaxError: invalid syntax
